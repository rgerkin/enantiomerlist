# %%
# %matplotlib inline
from IPython.display import HTML, display
import matplotlib.pyplot as plt
import numpy as np
import pyrfume
from pyrfume import pubchem
import re
import requests
from tqdm.auto import tqdm

# %%
def update_results(records, results):
    for annotation in records['Annotations']['Annotation']:
        try:
            cids = annotation['LinkedRecords']['CID']
        except:
            pass
        else:
            strings = [] 
            for x in annotation['Data']:
                for y in x['Value']['StringWithMarkup']:
                    strings.append(y['String'])
            for cid in cids:
                if cid in results:
                    results[cid] += strings
                elif strings:
                    results[cid] = strings

# %%
def get_results(heading):
    page = 1
    results = {}
    with tqdm(total=100) as pbar:
        while True:
            url = (f"https://pubchem.ncbi.nlm.nih.gov/rest/pug_view/annotations/heading/"
                   f"JSON?heading_type=Compound&heading={heading}&page={page}")
            response = requests.get(url)
            records = response.json()
            update_results(records, results)
            totalPages = records['Annotations']['TotalPages']
            if page==1:
                pbar.reset(total=totalPages)
            pbar.set_description("%d CIDs described" % len(results))
            pbar.update()
            page += 1
            if page > totalPages:
                break
    return results

# %%
pd_results = get_results("Optical+Rotation")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
pd_results
# Out:
# {263: ['Specific rotation: +9.8 at 20 °C/D (water)'],
#  7896: ['Specific optical rotation: -18.8 deg at 25 °C/D (ethanol) /(R)-(-)isomer/'],
#  5770: ['Specific optical rotation: -118 deg @ 23 °C/D (c= 1 in chloroform), -168 deg @ 26 °C/D (c= 0.624 in dimethylformamide), -164 deg @ 26 °C/D (c= 0.96 in pyridine); max absorption (chloroform): 216 nm, 267 nm, 295 nm (log e= 61,700; 17,000; 10,200)'],
#  2724385: ['Prisms from methanol  + chloroform. Decomposes at 225 °C. Specific optical rotation: +18.9 °C at 20 °C/D (pyridine). Very sparingly soluble in ethyl acetate /alpha-Acetyldigoxin/',
#   'Needles from alcohol + chloroform. Decomposes at 240 °C. Specific optical rotation: +30.4 °C at 20 °C/D (c = 1 in alcohol). More soluble in ethyl acetate than the alpha-form /beta-Acetyldigoxin/',
#   'Specific optical rotation: +13.4 to 13.8 deg at 25 °C/Hg (c = 10 in pyridine)',
#   'Specific optical rotation: +13.6 and +14.2 deg at 25 °C; 546.1 nm in anhydrous pyridine solution'],
#  441207: ['Specific optical rotation: +4.8 deg at 20 C/D (concn by volume = 1.2 g in 100 mL dioxane)',
#   'PURE DIGITOXIN HAS SPECIFIC OPTICAL ROTATION OF +18 TO +19 DEG IN CHLOROFORM'],
#  38853: ['Max absorption: 281 nm (e= 2780); Specific optical rotation (1 in 0.1 N HCl): -4.0 +/- 0.5 deg @ 23 °C/D'],
#  441074: ['Specific optical rotation @ 15 °C/D + 230 deg (concn by volume = 1.8 in chloroform); specific optical rotation @ 17 °C/D + 258 deg (alcohol); +322 deg (concn by volume = 1.6 in 2 M HCl); UV absorption spectrum is identical with that of quinine; blue fluorescence in dilute H2SO4.',
#   'MAX ABSORPTION (METHANOL): 230 NM (LOG E= 4.53); 280 NM (LOG E= 3.54); 336 NM (LOG E= 3.69); SPECIFIC OPTICAL ROTATION (ALCOHOL) @ 25 °C/D +212 DEG'],
#  68638786: ['Specific optical rotation @ 15 °C/D + 230 deg (concn by volume = 1.8 in chloroform); specific optical rotation @ 17 °C/D + 258 deg (alcohol); +322 deg (concn by volume = 1.6 in 2 M HCl); UV absorption spectrum is identical with that of quinine; blue fluorescence in dilute H2SO4.',
#   'MAX ABSORPTION (METHANOL): 230 NM (LOG E= 4.53); 280 NM (LOG E= 3.54); 336 NM (LOG E= 3.69); SPECIFIC OPTICAL ROTATION (ALCOHOL) @ 25 °C/D +212 DEG'],
#  10692: ['Specific optical rotation: +15 deg at 26 °C (concn = 1 g/100 ml water) /D-form/'],
#  14475285: ['Specific optical rotation: +15 deg at 26 °C (concn = 1 g/100 ml water) /D-form/'],
#  131854750: ['Specific optical rotation: +15 deg at 26 °C (concn = 1 g/100 ml water) /D-form/'],
#  222528: ['SPECIFIC OPTICAL ROTATION: +55 DEG (ALCOHOL) @ 20 °C/D'],
#  131204: ['Specific optical rotation: +29.5 deg at 20 °C/D (water, 5%)'],
#  442021: ['Specific optical rotation: -127 deg/D (chloroform), -85 deg/D (abs alc); max absorption (ethanol): 263 NM (log e= 4.09)',
#   'SPECIFIC OPTICAL ROTATION: -149.5 DEG @ 20 °C/5461 D'],
#  171548: ['Specific optical rotation: +92 deg at 22 °C (c=1 at 0.4% NaOH)',
#   'The specific optical rotation is +91.1 deg at 18 °C (c=1, 0.1 N NaOH) for 99% pure (+)-biotin.'],
#  444679: ['Plates or needles, mp 169-171 °C. Specific optical rotation: -71 deg at 23 °C/D ( c = 1.1 in CHCl3), -88 deg at /546 (CHCl3) /Benzoate/',
#   'UV irradiation gives vitamin D4 ... Solvated needles from ethyl acetate + methanol, mp 152-153 °C (dried). Specific optical rotation: -109 deg at 19 °C/D (CHCl3); also reported as needles from chloroform-methanol, mp 128-130 °C; Specific optical rotation: -121 deg at 19 °C/D ( c = 0.1). UV max: 262,272,282,294 nm (epsilon 8000, 11200, 11800, 6800). /22,23-Dihydro analog/',
#   'Specific optical rotation: -135 deg (in chloroform)',
#   'Specific optical rotation: -135 deg at 20 °C/D ( c = 1.2 in CHCL3, calcd as anhydr); -171 deg at 20 °C/546'],
#  7344: ['Specific optical rotation: -10 deg at 14 °C/D'],
#  54680660: ['Specific optical rotation: +23 deg at 20 °C, c = 1 in ethanol',
#   '[α]D/20 between + 21° and + 24° (5 % w/v in methanol solution)'],
#  24832091: ['SPECIFIC OPTICAL ROTATION: +26.1 DEG @ 20 °C/D (IN BENZENE)'],
#  8067: ['Optical rotation: +3.12 deg at 23 °C'],
#  25203: ['SPECIFIC OPTICAL ROTATION: +11.6 DEG IN WATER'],
#  21909702: ['SPECIFIC OPTICAL ROTATION: +11.6 DEG IN WATER'],
#  44135375: ['SPECIFIC OPTICAL ROTATION: +11.6 DEG IN WATER'],
#  56841640: ['SPECIFIC OPTICAL ROTATION: +11.6 DEG IN WATER'],
#  101611432: ['SPECIFIC OPTICAL ROTATION: +11.6 DEG IN WATER'],
#  637566: ['Specific optical rotation: -2 to +2 degrees'],
#  10690: ['SPECIFIC OPTICAL ROTATION: -3.49 TO +12.95 DEG @ 25 °C/D (WATER); MUTAROTATORY; SADTLER REFERENCE NUMBER: 8335 (IR, PRISM)',
#   'SPECIFIC OPTICAL ROTATION: -6.7 DEG @ 20 °C/D (CONCN= 1 G/100 ML WATER)'],
#  7027: ['Specific optical rotation = +63.5 deg to +6.2 deg at 25 °C (solvent= water) mutarotatory'],
#  24749: ['SPECIFIC OPTICAL ROTATION: +52.7 (WATER) @ 20 °C/D; MAX ABSORPTION (WATER): 282 NM (LOG E= 1.2); SADTLER REFERENCE NUMBER: 5455 (IR, PRISM); 199 (IR, GRATING)'],
#  107526: ['SPECIFIC OPTICAL ROTATION: +52.7 (WATER) @ 20 °C/D; MAX ABSORPTION (WATER): 282 NM (LOG E= 1.2); SADTLER REFERENCE NUMBER: 5455 (IR, PRISM); 199 (IR, GRATING)'],
#  33032: ['Specific optical rotation: +31.4 deg at 22.4 °C (6N HCl)',
#   'Specific optical rotation: +31.1 deg at 19 °C (dilute hydrochloric acid) /Hydrochloride/',
#   'Specific optical rotation: +23.5 deg to +25.5 deg (125 mg/mL 3.0 N hydrochloric acid) /Hydrochloride/',
#   '[α]D/20 between + 31,5° and + 32,2°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  3495: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  14982: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  128229: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  9897518: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  16213698: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  16395512: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  44260118: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  45356931: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  45358013: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  45358130: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  46783814: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  53312460: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  78577433: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  138106958: ['Specific optical rotation: +46.2 deg @ 17 °C/D (alcohol, 1.5%)'],
#  167560: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  23666328: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  23672308: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  23676143: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  23689119: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  70788954: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  86748263: ['Specific optical rotation: +24.2 to +25.5 deg at 25 °C/D (concn = 8.0 g in 100 mL 1.0 N hydrochloric acid)',
#   'L-Sodium glutamate is slightly levorotatory in water, but dextrorotatory in acid soln (the free L-acid is dextrorotatory)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)',
#   '[α]D/20 between + 24,8° and + 25,3°; (10 % solution (anhydrous basis) in 2N HCl, 200 mm tube)'],
#  54675810: ['Specific optical rotation: -17 deg at 16.5 °C/D (c = 1.8 in 0.01 N HCl); -16.6 deg at 20 °C/D (in water)',
#   '[α]D/25 10 % (w/v) aqueous solution between – 16,5° to – 18,0°'],
#  1549026: ['Specific optical rotation: -2 ro +2 degrees'],
#  1254: ['Specific optical rotation: +2.2 deg at 15 °C/D (alcohol solution)',
#   'Specific rotation: -45 to -51 deg (25 °C; l-menthol); -2 to +2 deg (dl-menthol) /89-78-1/'],
#  7794: ['Specific optical rotation: +13.09 deg at 18 °C/D; max absorption (alcohol): 235 nm (log e  = 1.93); 290 nm shoulder (log e = 1.08) /d-Citronellal/',
#   'Specific optical rotation: +11.50 deg at 25 °C/D',
#   'Specific optical rotation: -1 to +11 deg'],
#  8294: ['Angular rotation: -1 to +1 deg',
#   'Specific optical rotation: -9.45 deg at 20 °C/D; Sadtler Reference Number: 8341 (IR, prism)'],
#  6549: ['Angular rotation: -2 deg to +2 deg'],
#  5951: ['SPECIFIC OPTICAL ROTATION: -6.83 DEG @ 20 °C/D (1.5 G IN 15 G AQ SOLN); +14.45 DEG @ 25 °C/D (C= 0.5 G IN 5.6 NORMAL HCL)'],
#  23667548: ['Specific optical rotation: +104.4 deg at 20 °C/D (c = 2.4)',
#   '[α]D/20 between + 103° and + 106° (10 % w/v aqueous solution)'],
#  6466: ['Needles from benzene and methanol, mp = 209-210 °C. Specific optical rotation = +75 deg at 20 °C/D ( c = 0.5 moles/L) /Methyl ester',
#   'Specific optical rotation: +86 deg at 19 °C/D (conc= 2.12 g in 100 ml water)'],
#  6251: ['Specific optical rotation: -0.49 deg @ 25 °C/D (water)'],
#  6654: ['Specific optical rotation: +33.52 at 20 °C/D (alcohol) /d-Form, hydrochloride/'],
#  5780: ['Specific optical rotation: -2.0 deg at 20 °C/D (water)'],
#  6173: ['Specific optical rotation: +88 deg at 20 °C/D (p = 70)'],
#  2735101: ['Specific optical rotation: +88 deg at 20 °C/D (p = 70)'],
#  5284498: ['Specific optical rotation: +88 deg at 20 °C/D (p = 70)'],
#  1072: ['Specific optical rotation: -112 to -122 deg at 25 °C/D (0.0 N sodium hydroxide, 0.5%; -8.80 deg (water) sodium line',
#   'The specific optical rotation in acid or neutral solutions is +56.5-59.5 deg at 20 °C (0.5%, dil HCl).',
#   '[α]D/20 between – 115° and – 140° in a 0,05 N sodium hydroxide solution'],
#  6759: ['Specific optical rotation: -112 to -122 deg at 25 °C/D (0.0 N sodium hydroxide, 0.5%; -8.80 deg (water) sodium line',
#   'The specific optical rotation in acid or neutral solutions is +56.5-59.5 deg at 20 °C (0.5%, dil HCl).',
#   '[α]D/20 between – 115° and – 140° in a 0,05 N sodium hydroxide solution'],
#  493570: ['Specific optical rotation: -112 to -122 deg at 25 °C/D (0.0 N sodium hydroxide, 0.5%; -8.80 deg (water) sodium line',
#   'The specific optical rotation in acid or neutral solutions is +56.5-59.5 deg at 20 °C (0.5%, dil HCl).',
#   '[α]D/20 between – 115° and – 140° in a 0,05 N sodium hydroxide solution'],
#  71310809: ['Specific optical rotation: -112 to -122 deg at 25 °C/D (0.0 N sodium hydroxide, 0.5%; -8.80 deg (water) sodium line',
#   'The specific optical rotation in acid or neutral solutions is +56.5-59.5 deg at 20 °C (0.5%, dil HCl).',
#   '[α]D/20 between – 115° and – 140° in a 0,05 N sodium hydroxide solution'],
#  54670067: ['Specific optical rotation (c = 1 in water): +20.5 to +21.5 deg at 25 °C/D; (c = 1 in methanol): +48 deg at 23 °C/D',
#   'Specific optical rotation: +24 deg at 20 °C/D (in water, 1%)',
#   '[α]D/20 between + 20,5° and + 21,5° (10 % w/v aqueous solution)'],
#  3249: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  5280793: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  5315257: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  5353610: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  5702050: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  6372069: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  6536972: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  7067801: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  11003810: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  12358706: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  44630173: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  58855793: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  86280331: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  87070941: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  91555781: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  122164949: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  122172962: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  134129658: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  134715773: ['Specific optical rotation: +82.6 @ 25 °C/D (c= 3 in acetone); +102.5 @ 20 °C/D (alcohol); specific optical rotation: +52 @ 20 °C/D (chloroform); UV max absorption (hexane): 264.5 nm (e= 458.9 +/- 7.5, 1%, 1 cm)'],
#  5280795: ['Specific optical rotation (1.6% in acetone): +84.8 deg at 20 °C/D; (1.6% in chloroform): +51.9 deg at 20 °C/D'],
#  6675: ['Specific optical rotation: +24 deg at 20 °C/D (concentration = 3 mg in 100 mL water) /Sodium taurocholate/',
#   'Specific optical rotation: +25.6 deg at 20 °C/D /Barium taurocholate/',
#   'Specific optical rotation: +38.8 deg at 18 °C/D (concn = 2 mg in 100 mL alcohol)'],
#  10255083: ['Specific optical rotation (water): +51.6 deg at 15 °C/654 angstroms'],
#  86312167: ['Specific optical rotation (water): +51.6 deg at 15 °C/654 angstroms'],
#  10049: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  10492: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  64685: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  512289: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  657014: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  1201518: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  6321405: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  6552009: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  18639728: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  44630107: ['Specific optical rotation: +37.7 deg at 20 °C/D (alc, 5%), specific optical rotation: +44.4 deg at 22 °C/546 (toluene, 0.5%) /D-Borneol/',
#   'Specific optical rotation: -37.7 deg at 20 °C/D (alc, 5%); -44.4 deg at 22   °C/546 (toluene, 0.5%) /L-Borneol/'],
#  179: ['OPTICALLY ACTIVE COMPD; OPTICAL ROTATION: -39.4 DEG (PURE) AND -105 DEG (AQ SOLN) AT 20 °C'],
#  221493: ['Specific optical rotation: +37 deg at 20 °C/D (c = 0.6 in alcohol)'],
#  9290: ['Specific optical rotation: approximately +6 deg at 20 °C/D'],
#  6613: ['Very hygroscopic crystals. Specific optical rotation: + 27.1 deg at 25 °C/D (C = 2) /Pantothenic acid, sodium salt/',
#   'Minute needles from methyl alcohol; sweetish taste with slightly bitter aftertaste; decomposes 195-196 °C; moderately hygroscopic. Specific optical rotation: +28.2 deg at 25 °C/D (c = 5). 1 g dissolves in 2.8 mL water. Soluble in glycerol; slightly soluble in alcohol, acetone. pH of 5% aq soln: 7.2 - 8.0; pH in CO2-free water: 8.7 /Calcium salt/',
#   'Specific optical rotation: 37.5 deg at 25 °C/D'],
#  167945: ['Very hygroscopic crystals. Specific optical rotation: + 27.1 deg at 25 °C/D (C = 2) /Pantothenic acid, sodium salt/',
#   'Minute needles from methyl alcohol; sweetish taste with slightly bitter aftertaste; decomposes 195-196 °C; moderately hygroscopic. Specific optical rotation: +28.2 deg at 25 °C/D (c = 5). 1 g dissolves in 2.8 mL water. Soluble in glycerol; slightly soluble in alcohol, acetone. pH of 5% aq soln: 7.2 - 8.0; pH in CO2-free water: 8.7 /Calcium salt/',
#   'Specific optical rotation: 37.5 deg at 25 °C/D'],
#  145742: ['SPECIFIC OPTICAL ROTATION: -80.9 DEG @ 20 °C/D (WATER, 1%); SADTLER REF NUMBER: 1905 (IR, PRISM)',
#   'Specific optical rotation: -85.0 at 23.4 °C/D; -52.6 at 20 °C/D (0.50N hydrochloric acid, 0.58%); -93.9 deg at 20 °C/D (0.6N potassium hydroxide, 2.4%)'],
#  5284430: ['Crystals. Delliquescent. Specific optical rotation = +104 deg at 20 °C/D ( p = 10) /l-Form/'],
#  637563: ['SPECIFIC OPTICAL ROTATION: +0.08 DEG'],
#  6322: ['Specific optical rotation: +26.9 deg @ 20 °C/C (c= 1.65 in 6.0 N hydrochloric acid)'],
#  5960: ['Specific optical rotation: -2.0 deg at 25 °C (c=3.93 in 5N HCl) /d-Aspartic acid/',
#   'Specific optical rotation: +25.0 deg (c= 1.97 g in 100 ml 6 N hydrochloric acid) at 20 °C/D',
#   'SPECIFIC OPTICAL ROTATION (WATER): +4.36 DEG @ 20 °C/D'],
#  6197: ['Specific optical rotation: -3.38 deg @ 29 °C/D (9.47% in methanol); +6.8 deg @ 25 °C/D (2% in water)',
#   'Specific optical rotation: -33 deg @ 25 °C/D (1% in chloroform)'],
#  441140: ['SPECIFIC OPTICAL ROTATION: +370 DEG @ 17 °C/D (SATURATED CHLOROFORM SOLN)',
#   'MAX ABSORPTION (ALCOHOL): 291 NM (LOG E= 4.37); 325 NM (LOG E= 3.77); SPECIFIC OPTICAL ROTATION: +337 DEG @ 21 °C/D (ACETONE)'],
#  6758: ['Specific optical rotation: -228 deg at 20 °C/D (concentration by vol = 2.22 g in 100 mL benzene)',
#   'Specific optical rotation: -225.2 deg at 29.5 °C/D (benzene)',
#   'Strongly levorotatory in solution; specific rotation for D line 230 deg in benzene, 62 deg in ethylene dichloride.'],
#  19649: ['Very hygroscopic, decomposes at about 200 °C. Specific optical rotation: -76 deg at 25 °C/D /Streptomycin trihydrochloride-calcium chloride double salt/'],
#  5950: ['Specific optical rotation= +2.42 °For D-sodium line at 25 °C (c = 10 in H2O); +13.7 °For D sodium line at 25 °C (c = 2.063 in 6N HCl)',
#   'SPECIFIC OPTICAL ROTATION: +2.8 DEG @ 25 °C/D (WATER, CONCN= 6%); SPECIFIC OPTICAL ROTATION: +9.55 DEG @ 25 °C/D (HYDROCHLORIC ACID)'],
#  6274: ['Specific optical rotation:(c=0.77 in 0.5N of NaOH): -10.9 °C at 20 °C/D; (c=0.75 to 3.77): -38.95 °C at 25 °C/D; (c=1.00-4.05 in 6.1N HCl): +13.34 °C at 25 °C/D',
#   'Specific optical rotation (1.13% in water): -39.7 @ 20 °C/D'],
#  6140: ['Specific optical rotation: -35.1 deg at 20 °C/D (c = 1.94)',
#   'Specific optical rotation: +70 deg at 18 °C/D (water)'],
#  6850740: ['Specific optical rotation: +11 to +24 deg at 20 °C'],
#  14030006: ['Dextrorotatory (undiluted in sodium light)'],
#  23308252: ['Specific optical rotation: +1 to +8 at 20 °C/D'],
#  441071: ['Specific optical rotation: -139 deg at 18 °C/D (c = 0.4 in chloroform); -104.3 deg at 20 °C/D (c = 0.254 in alcohol)'],
#  135398658: ['Specific optical rotation: +23 deg at 25 °C/D (c= 0.5 in 0.1 N sodium hyroxide)'],
#  6057: ['SPECIFIC OPTICAL ROTATION: -10.6 DEG @ 22 °C/D (C= 4 IN N HYDROCHLORIC ACID)'],
#  5962: ['Crystals from ethanol + ether, mp 193 °C. Specific optical rotation: +15.3 deg at 20 °C/D (C = 2) /Lysine dihydrochloride/',
#   'Specific optical rotation: +14.6 at 20 °C/D (c = 6.5); +25.9 at 23 °C/D (c = 2 in 6.0N HCl)'],
#  5862: ['Decomposes 175-178 °C; soluble in water, alcohol, acetone; the aqueous solution is acid; decomposes and oxidizes slowly; hygroscopic. Specific optical rotation: +5.0 °C (5 N HCl) at 25 °C/D; +10.0 °C at 25 °C/D (glacial acetic acid) /Cysteine hydrochloride/',
#   'Specific optical rotation: +6.5 deg at 25 °C/D (5 N HCl); +13.0 deg at 25 °C/D (glacial acetic acid)',
#   'Specific optical rotation: +9.7 deg (c = 8 in 1M HCl) at 25 °C/D'],
#  60960: ['Decomposes 175-178 °C; soluble in water, alcohol, acetone; the aqueous solution is acid; decomposes and oxidizes slowly; hygroscopic. Specific optical rotation: +5.0 °C (5 N HCl) at 25 °C/D; +10.0 °C at 25 °C/D (glacial acetic acid) /Cysteine hydrochloride/',
#   'Specific optical rotation: +6.5 deg at 25 °C/D (5 N HCl); +13.0 deg at 25 °C/D (glacial acetic acid)',
#   'Specific optical rotation: +9.7 deg (c = 8 in 1M HCl) at 25 °C/D'],
#  446937: ['Decomposes 175-178 °C; soluble in water, alcohol, acetone; the aqueous solution is acid; decomposes and oxidizes slowly; hygroscopic. Specific optical rotation: +5.0 °C (5 N HCl) at 25 °C/D; +10.0 °C at 25 °C/D (glacial acetic acid) /Cysteine hydrochloride/',
#   'Specific optical rotation: +6.5 deg at 25 °C/D (5 N HCl); +13.0 deg at 25 °C/D (glacial acetic acid)',
#   'Specific optical rotation: +9.7 deg (c = 8 in 1M HCl) at 25 °C/D'],
#  5460971: ['Decomposes 175-178 °C; soluble in water, alcohol, acetone; the aqueous solution is acid; decomposes and oxidizes slowly; hygroscopic. Specific optical rotation: +5.0 °C (5 N HCl) at 25 °C/D; +10.0 °C at 25 °C/D (glacial acetic acid) /Cysteine hydrochloride/',
#   'Specific optical rotation: +6.5 deg at 25 °C/D (5 N HCl); +13.0 deg at 25 °C/D (glacial acetic acid)',
#   'Specific optical rotation: +9.7 deg (c = 8 in 1M HCl) at 25 °C/D'],
#  6419722: ['Decomposes 175-178 °C; soluble in water, alcohol, acetone; the aqueous solution is acid; decomposes and oxidizes slowly; hygroscopic. Specific optical rotation: +5.0 °C (5 N HCl) at 25 °C/D; +10.0 °C at 25 °C/D (glacial acetic acid) /Cysteine hydrochloride/',
#   'Specific optical rotation: +6.5 deg at 25 °C/D (5 N HCl); +13.0 deg at 25 °C/D (glacial acetic acid)',
#   'Specific optical rotation: +9.7 deg (c = 8 in 1M HCl) at 25 °C/D'],
#  5288826: ['Yellowish-white powder; slight acetic odor. Specific optical rotation (15 °C): 77 deg (water). One g dissolves in 2.25 m: water, 2 m\\L boiling water, 22 mL alcohol, 2 mL alcohol at 60 °C, 4.5 mL glycerol, 4.75 mL chloroform. Practically insoluble in ether. /Acetate trihydrate/',
#   'Specific optical rotation: -132 deg at 25 °C/D (methanol)'],
#  5359371: ['SPECIFIC OPTICAL ROTATION: -88.9 DEG @ 20 °C/D (METHANOL, 3%)'],
#  10219: ['SPECIFIC OPTICAL ROTATION: -50 DEG @ 20 °C/D (CHLOROFORM, 2%)'],
#  6000: ['Hexagonal and pentagonal microplatelets from water. Can exist in the form of various hydrates. The anhydrous materl (dec 274-275 °C) takes up water in moist atm until it reaches the pentahydrate stage, dec approximately 270 °C. Specific optical rotation: +190 deg @ 22 °C/D; +219 deg @ 23 °C/D (c= 0.785 in methanol). UV max (H2O): 280 nm (E=118, 1%, 1 cm). /Chloride, d-Form/'],
#  5051: ['Specific optical rotation: -97 deg @ 24 °C/D (c= 1 in chloroform); UV max absorption (methanol): 228, 302 nm (log e= 4.79, 4.48)'],
#  32681: ['Specific optical rotation: -97 deg @ 24 °C/D (c= 1 in chloroform); UV max absorption (methanol): 228, 302 nm (log e= 4.79, 4.48)'],
#  5280954: ['Specific optical rotation: -97 deg @ 24 °C/D (c= 1 in chloroform); UV max absorption (methanol): 228, 302 nm (log e= 4.79, 4.48)'],
#  5353923: ['Specific optical rotation: -97 deg @ 24 °C/D (c= 1 in chloroform); UV max absorption (methanol): 228, 302 nm (log e= 4.79, 4.48)'],
#  439302: ['SPECIFIC OPTICAL ROTATION: -26.2 DEG @ 22 °C/D (0.53 G/100 ML WATER)'],
#  1065: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  8549: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  441073: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  637552: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  2728270: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  3034034: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  5748152: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  14822542: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  44630461: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  91927769: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  91971361: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  129316724: ['Dull needles or rods, making a light and readily compressible mass. Becomes brownish on exposure to light. Loses its water of crystalization at about 100 °C. Specific optical rotation: -220 deg at 16 °C/D (5% solution in about 0.5N HCl). One gram dissolves in 810 mL water, 32 mL boiling water, 120 mL alcohol, 10 mL alcohol at 78 °C. Slightly soluble in chloroform, ether but freely soluble in a mixture of 2 volumes chloroform and 1 volume absolute alcohol. Aqueous solutions are neutral to litmus, pH of saturated solution 6.2 /Quinine sulfate dihydrate/',
#   'Specific optical rotation: -169 deg at 15 °C/D (concentration = 2 g in 100 mL 97% alcohol); specific optical rotation: -117 deg at 17 °C/D (concentration = 1.5 g in 100 mL chloroform); specific optical rotation: -285 deg at 15 °C/D (concentration = 0.4 molar in 0.1N sulfuric acid',
#   'Specific optical rotation: + 212 deg at 25 °C/D (alcohol); prisms; needles from water. /d-quinidine sulfate/'],
#  2724224: ['Specific optical rotation: +34.6 deg at 15 °C/D (concn= 1.84 g in 100 mL water)'],
#  13652278: ['Specific optical rotation: +34.6 deg at 15 °C/D (concn= 1.84 g in 100 mL water)'],
#  14985: ['Specific optical rotation: -3.0 deg at 25 °C/546.1 °C (benzene);  +0.32 deg at 25 °C/546.1 °C (ethanol)',
#   'Specific optical rotation: +0.65 at 25 °C/D (alc)',
#   '[α]D/25 0° ± 0,05° (1 in 10 solution in chloroform)'],
#  5144: ['Specific optical rotation: -0 deg 30 min at 15 °C'],
#  184933: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  2734998: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  5311498: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  5460135: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  6442967: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  6474318: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  10887743: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  11970261: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  22836442: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  23806828: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  24892734: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  25102581: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  25195380: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  44176380: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  45357148: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  46853873: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  54605677: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  70678590: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  91898871: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  118701720: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  123134034: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  124080944: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  129627537: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  129627679: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  129893524: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  132980806: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  137332389: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  139030973: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  145705982: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  145875202: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  152743321: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  154825555: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  156587311: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  156619387: ['SPECIFIC OPTICAL ROTATION: -59 + or - 9 DEG @ 23 °C 656 NM (DILUTE AQ SOLN)'],
#  6231: ['Specific optical rotation: +108 deg (chloroform, 1%)'],
#  12035: ['Specific optical rotation: +5 deg at 20 °C (concn = 3 g/100 mL water)'],
#  1972: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  14956: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  5280965: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  5386092: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  16667679: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  23863720: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  44399170: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
#  44421047: ['Specific optical rotation at 24 °C/D: +333 deg (acidic N,N-dimethylformamide); -33.6 deg (0.1 N methanolic hydrochloric acid)'],
# ...
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  5460441: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  14060299: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  24207713: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  46782672: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  73759704: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  91885464: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  133640187: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  138106885: ['Specific optical rotation: -49 deg at 20 °C/D (methanol); UV max absorption 2 (methanol): 227, 273, nm (E= 29,800,1700)',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees',
#   '(c = 1, MeOH) \t\t[a]20D = -53 +- 20 degrees'],
#  55245: ['Specific optical rotation: +138.5 deg at 20 °C/D (concentration by volume = 0.5 g in 100 ml chloroform)'],
#  9444: ['Optical rotation: + 39 degrees @ 25 °C (c = 1 in water)',
#   '(c = 1, H2O) [a]20 D = 40.0 ± 1.0°'],
#  2909: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  5280754: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  5284373: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  5458585: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  5497195: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  16404350: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  24883466: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  49867938: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  71306795: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  71463825: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  73896891: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  123134263: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  123134270: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  129009974: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  132274082: ['Optical rotation: -244 degrees @ 20 °C (c = 0.6 in chloroform), - 189 degrees @ 20 °C (c = 0.5 in methanol)'],
#  34457: ['Optical rotation: + 92.9 degrees @ 24 °C (c = 1.06 in chloroform)'],
#  281327: ['Optical rotation: + 92.9 degrees @ 24 °C (c = 1.06 in chloroform)'],
#  146158504: ['Optical rotation: + 92.9 degrees @ 24 °C (c = 1.06 in chloroform)'],
#  40839: ['Optical rotation: +39.4 deg (c = 1.0 in methanol)'],
#  148124: ['Specific optical rotation: - 36 deg (c = 0.74 in ethanol)'],
#  92431: ['Specific optical rotation: +45.4 deg at 20 °C/D (c = 2 in acetone)'],
#  439504: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  5062352: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  5280440: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  6260974: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  6474983: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  12873441: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  12873460: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  23277825: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  24870678: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  45357419: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  66509091: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  73440817: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  101000161: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  126843096: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  129606990: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  133109136: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  134693945: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  137698429: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  154825567: ['Specific optical rotation: -46 deg at 25 °C/D (c = 2 cm methanol)'],
#  5266: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  5284619: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  5289394: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  5353959: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  5356392: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  5702243: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  6376223: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  6419898: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  6440717: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  44629935: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  53384896: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  71729958: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  76324338: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  129627802: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  131674879: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  134687906: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  134715567: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  134717663: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  135391165: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  137704528: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  138106574: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  145712264: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  153274329: ['Specific optical rotation: -80 deg at 20 °C/D'],
#  71674: ['Specific optical rotation at 20 °C/D = +0.8 deg (c = 1.165 in absolute ethanol); -7.7 deg (c = 1.083 in chloroform)'],
#  21872770: ['Specific optical rotation at 20 °C/D = +0.8 deg (c = 1.165 in absolute ethanol); -7.7 deg (c = 1.083 in chloroform)'],
#  16132294: ['Specific optical rotation = -96 deg at 25 °C/D (error within 2 deg) (c = 0.62 in 0.1N HCl). UV max (0.1N HCL): 280 nm. The absorbance of a solution containing one gram per 100 mL contained in a cell having an absorption path of one cm = 42.0 /alpha-Avoparcin/',
#   'Specific optical rotation = -102 deg at 25 °C/D (error within 2 deg) (c = 0.65 in 0.1N HCl). UV max (0.1N HCl): 280 nm. The absorbance of a solution containing one gram per 100 ml contained in a cell having an absorption path of one cm = 44.0 /beta-Avoparcin/'],
#  22835777: ['Specific optical rotation = -96 deg at 25 °C/D (error within 2 deg) (c = 0.62 in 0.1N HCl). UV max (0.1N HCL): 280 nm. The absorbance of a solution containing one gram per 100 mL contained in a cell having an absorption path of one cm = 42.0 /alpha-Avoparcin/',
#   'Specific optical rotation = -102 deg at 25 °C/D (error within 2 deg) (c = 0.65 in 0.1N HCl). UV max (0.1N HCl): 280 nm. The absorbance of a solution containing one gram per 100 ml contained in a cell having an absorption path of one cm = 44.0 /beta-Avoparcin/'],
#  5151: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  3085092: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  6473797: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  16057833: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  133126597: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  138106903: ['MW: 140-142 °C. Specific optical rotation = -37 deg at 25 °C/D (sodium) line (c = 1 in ethanol) /Salinomycin sodium salt/',
#   'Specific optical rotation = -63 deg at 25 °C/D (sodium) line (c = 1 in ethanol)'],
#  60823: ['White to off-white crystalline powder. Specific optical rotation at 25 °C for D (sodium) line = -7.4 deg (c = 1 in DMSO). Freely soluble in methanol; slightly soluble in ethanol; very slightly soluble in acetonitrile, distilled water, phosphate buffer (pH 7.4). Insoluble in aqueous solutions of pH 4 and below. /Atorvastatin calcium salt trihydrate/'],
#  2771: ['Specific optical rotation: +12.33 at 25 °C/D (c = 1 in methanol) /Citolapram escitalopram/'],
#  3034683: ['Specific optical rotation at 31 °C for D (sodium) line = -70.5 deg (c=2 in methanol).'],
#  7568320: ['Specific optical rotation at 31 °C for D (sodium) line = -70.5 deg (c=2 in methanol).'],
#  266461: ['Specific optical rotation for D (sodium) line = -13.7 deg'],
#  6435894: ['Specific optical rotation at 23 °C for D (sodium) line = +47.04 deg (2 percent in methanol).'],
#  5362124: ['Specific optical rotation: -159 deg at 25 °C/D (c = 1.2 in ethanol)'],
#  5997: ['Specific rotation: -34 to 38 deg @ 25 °C'],
#  60613: ['Specific optical rotation at 20 °C for the D (sodium) line: -97.3 deg (c=0.80 in water)'],
#  5646: ['Specific optical rotation at 16 °C for the D (sodium) line: +509.4 deg (c=0.697 in chloroform) /Monobasic acid/'],
#  2269: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  55185: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  447043: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  456416: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  3086605: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  6324605: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  10771356: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  44317861: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  90489754: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  119057560: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  129396765: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  133109198: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  134693946: ['Specific optical rotation: -37 °C at 20 °C/D (c = 1 on CHCl3)'],
#  ...}

# %%
path = 'pubchem/pubchem_scrape_optical_rotation.pkl'
# Then do something to save the data so you don't have to scrape it every time.
